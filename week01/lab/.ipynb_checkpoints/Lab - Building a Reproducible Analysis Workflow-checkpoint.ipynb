# %% [markdown]
# # Lab: Building a Reproducible Analysis Workflow
#
# In the first part of this lab, you will use official National Park Service data to answer a guided question. In the second part, you will find a dataset and conduct an analysis of your own.
#
# Use the workflow from lecture throughout the lab:
#
# 1. **Question**
# 2. **Data**
# 3. **Operation**
# 4. **Check**
# 5. **Evidence**
# 6. **Conclusion**
# 7. **Limitation**

# %% [markdown]
# ## Learning goals
#
# By the end of this lab, you should be able to:
#
# - organize an investigation with the reproducible analysis workflow;
# - inspect a dataset before analyzing it;
# - group, summarize, check, and sort observations with Pandas;
# - formulate a research question that can be answered with data; and
# - distinguish evidence, conclusions, and limitations.

# %% [markdown]
# ## Using AI tools responsibly
#
# You may use AI to ask questions, debug code, or receive feedback. You remain responsible for understanding your work, verifying suggestions against the data, and citing the source of your dataset. At the end, disclose whether you used an AI tool. Using AI is not required.

# %% [markdown]
# # Part 1: Florida park visitation

# %% [markdown]
# ## Background
#
# The National Park Service (NPS) publishes estimates of recreational visits to its units. These estimates help parks understand patterns in public use and plan staffing, maintenance, transportation, and visitor services.
#
# This course file contains monthly estimates for five Florida NPS units from 2015 through 2025:
#
# - Big Cypress National Preserve
# - Biscayne National Park
# - Canaveral National Seashore
# - Dry Tortugas National Park
# - Everglades National Park
#
# A recreational visit is a visit, not necessarily one unique person. A person who visits several times may be counted several times.

# %% [markdown]
# | Feature | Description |
# | --- | --- |
# | `park_code` | Four-letter NPS unit code |
# | `park` | Name of the NPS unit |
# | `year` | Calendar year of the observation |
# | `month_number` | Month represented as an integer from 1 through 12 |
# | `month` | Month name |
# | `recreation_visits` | Estimated recreational visits during that park-month |

# %% [markdown]
# ## Step 1: Question
#
# **After the decline in July 2020, when did Canaveral National Seashore's July recreational visitation first return to or exceed its average July visitation from 2015–2019?**
#
# The 2015–2019 mean provides a pre-pandemic comparison point. In this question, “recovery” means the first July from 2020 onward with visitation at or above that baseline. This definition does not require every later July to remain above the baseline.

# %% [markdown]
# ## Step 2: Data
#
# Import Pandas using the alias `pd`. Read `data/nps_florida_park_visitation_2015_2025.csv` into a DataFrame named `park_visits`, then display its first five rows.

# %%
# Write your code here.
import pandas as pd

park_visits = pd.read_csv("data/nps_florida_park_visitation_2015_2025.csv")
park_visits.head(5)
# Out:
#   park_code                           park  ...     month  recreation_visits
# 0      BICY  Big Cypress National Preserve  ...   January             114045
# 1      BICY  Big Cypress National Preserve  ...  February             144112
# 2      BICY  Big Cypress National Preserve  ...     March             153084
# 3      BICY  Big Cypress National Preserve  ...     April             113880
# 4      BICY  Big Cypress National Preserve  ...       May              72510
#
# [5 rows x 6 columns]

# %% [markdown]
# Display the last five rows.

# %%
# Write your code here.
park_visits.tail(5)
# Out:
#     park_code                      park  ...      month  recreation_visits
# 655      EVER  Everglades National Park  ...     August              50464
# 656      EVER  Everglades National Park  ...  September              32290
# 657      EVER  Everglades National Park  ...    October              19008
# 658      EVER  Everglades National Park  ...   November              53416
# 659      EVER  Everglades National Park  ...   December              70926
#
# [5 rows x 6 columns]

# %% [markdown]
# Display information about the DataFrame and calculate the number of missing observations in each feature.

# %%
# Write your code here.
park_visits.describe()
# Out:
#               year  month_number  recreation_visits
# count   660.000000    660.000000         660.000000
# mean   2020.000000      6.500000       83304.665152
# std       3.164676      3.454671       73216.283918
# min    2015.000000      1.000000         176.000000
# 25%    2017.000000      3.750000       30373.750000
# 50%    2020.000000      6.500000       63529.500000
# 75%    2023.000000      9.250000      121226.750000
# max    2025.000000     12.000000      401190.000000

# %%
park_visits.isnull().sum()
# Out:
# park_code            0
# park                 0
# year                 0
# month_number         0
# month                0
# recreation_visits    0
# dtype: int64

# %% [markdown]
# **What does each row represent?**
#
# Your answer: Monthly recreational visits to a specific Florida National Park

# %% [markdown]
# **Are any observations missing from the six features?**
#
# Your answer: No

# %% [markdown]
# ## Step 3: Operation
#
# Create one Boolean condition that identifies Canaveral National Seashore and another that identifies July.

# %%
# Write your code here.
park_visits[park_visits["park"] == "Canaveral National Seashore"]
# Out:
#     park_code                         park  ...      month  recreation_visits
# 264      CANA  Canaveral National Seashore  ...    January             108691
# 265      CANA  Canaveral National Seashore  ...   February             110041
# 266      CANA  Canaveral National Seashore  ...      March             200878
# 267      CANA  Canaveral National Seashore  ...      April             168201
# 268      CANA  Canaveral National Seashore  ...        May             191627
# ..        ...                          ...  ...        ...                ...
# 391      CANA  Canaveral National Seashore  ...     August             227762
# 392      CANA  Canaveral National Seashore  ...  September             189143
# 393      CANA  Canaveral National Seashore  ...    October              78143
# 394      CANA  Canaveral National Seashore  ...   November             175034
# 395      CANA  Canaveral National Seashore  ...   December             172561
#
# [132 rows x 6 columns]

# %%
park_visits[park_visits["month"] == "July"].head()
# Out:
#    park_code                           park  ...  month  recreation_visits
# 6       BICY  Big Cypress National Preserve  ...   July              78688
# 18      BICY  Big Cypress National Preserve  ...   July              63078
# 30      BICY  Big Cypress National Preserve  ...   July              72270
# 42      BICY  Big Cypress National Preserve  ...   July              46520
# 54      BICY  Big Cypress National Preserve  ...   July              49956
#
# [5 rows x 6 columns]

# %% [markdown]
# Combine the two conditions with `&`. Use `.loc` to select the `year` and `recreation_visits` features, make a copy named `canaveral_july`, and display it.

# %%
# Write your code here.
# I think you would read this as "In park visits: locate where the month is July & the park is Canaveral National Seashore"?
canaveral_july = park_visits.loc[
        park_visits["month"].isin(["July"])
        & park_visits["park"].isin(["Canaveral National Seashore"])
    ].copy()

canaveral_july
# Out:
#     park_code                         park  ...  month  recreation_visits
# 270      CANA  Canaveral National Seashore  ...   July             163169
# 282      CANA  Canaveral National Seashore  ...   July             216437
# 294      CANA  Canaveral National Seashore  ...   July             138018
# 306      CANA  Canaveral National Seashore  ...   July             189285
# 318      CANA  Canaveral National Seashore  ...   July             162947
# 330      CANA  Canaveral National Seashore  ...   July             112898
# 342      CANA  Canaveral National Seashore  ...   July             206636
# 354      CANA  Canaveral National Seashore  ...   July             233352
# 366      CANA  Canaveral National Seashore  ...   July             173296
# 378      CANA  Canaveral National Seashore  ...   July             176242
# 390      CANA  Canaveral National Seashore  ...   July             253403
#
# [11 rows x 6 columns]

# %% [markdown]
# Create `pre_pandemic_condition`, which is `True` for years from 2015 through 2019. Use it with `.loc` to calculate the mean of `recreation_visits`, and store the result as `pre_pandemic_july_mean`.
#
# Display `pre_pandemic_july_mean`.

# %%
# Write your code here.
pre_pandemic_condition = canaveral_july.loc[
        canaveral_july["year"].between(2015, 2019)
    ]

pre_pandemic_condition
# Out:
#     park_code                         park  ...  month  recreation_visits
# 270      CANA  Canaveral National Seashore  ...   July             163169
# 282      CANA  Canaveral National Seashore  ...   July             216437
# 294      CANA  Canaveral National Seashore  ...   July             138018
# 306      CANA  Canaveral National Seashore  ...   July             189285
# 318      CANA  Canaveral National Seashore  ...   July             162947
#
# [5 rows x 6 columns]

# %%
pre_pandemic_july_mean = pre_pandemic_condition["recreation_visits"].mean()
pre_pandemic_july_mean
# is it supposed to output as np.float64(173971.2)??
# Out:
# np.float64(173971.2)

# %% [markdown]
# Create a condition that identifies rows from 2020 onward whose `recreation_visits` are greater than or equal to `pre_pandemic_july_mean`. Use `.loc` to create `recovery_years`, then display it in ascending year order.

# %%
# Write your code here.
recovery_years = canaveral_july.loc[
        (canaveral_july["year"] >= 2020)
        & (canaveral_july["recreation_visits"] >= pre_pandemic_july_mean)
    ].copy()
recovery_years.sort_values(by="year", ascending=True, inplace=True)
recovery_years
# Out:
#     park_code                         park  ...  month  recreation_visits
# 342      CANA  Canaveral National Seashore  ...   July             206636
# 354      CANA  Canaveral National Seashore  ...   July             233352
# 378      CANA  Canaveral National Seashore  ...   July             176242
# 390      CANA  Canaveral National Seashore  ...   July             253403
#
# [4 rows x 6 columns]

# %% [markdown]
# ## Step 4: Check
#
# Display the number of rows in `canaveral_july`, its smallest year, and its greatest year.

# %%
# Write your code here.
# number of rows (11)
canaveral_july["park"].count()
# Out:
# np.int64(11)

# %%
#smallest year (2015)
canaveral_july["year"].min()
# Out:
# np.int64(2015)

# %%
#greatest year (2025)
canaveral_july["year"].max()
# Out:
# np.int64(2025)

# %% [markdown]
# **Do these results confirm that the filtered data contains one July observation for every year from 2015 through 2025?**
#
# Your answer: Yes

# %% [markdown]
# Count the observations used to calculate `pre_pandemic_july_mean`.

# %%
# Write your code here.
pre_pandemic_condition["year"].count()
# Out:
# np.int64(5)

# %% [markdown]
# **Does the baseline use the expected five years?**
#
# Your answer: Yes

# %% [markdown]
# ## Step 5: Evidence
#
# Display the first row of `recovery_years`.

# %%
# Write your code here.
recovery_years.head(1)
# Out:
#     park_code                         park  ...  month  recreation_visits
# 330      CANA  Canaveral National Seashore  ...   July             112898
#
# [1 rows x 6 columns]

# %% [markdown]
# **What was the 2015–2019 mean, and which year first met or exceeded it after the July 2020 decline? Report that year's July visitation.**
# Your answer:
# Mean: 173971.2
# First Year to exceed: 2021
# Visitation during July 2021: 206636

# %% [markdown]
# ## Step 6: Conclusion

# %% [markdown]
# **Write one sentence that answers the research question using the evidence.**
#
# Your answer:
# Canaveral National Seashore's July recreational visitation first exceeded its pre-pandemic average July visitation in 2021.

# %% [markdown]
# ## Step 7: Limitation

# %% [markdown]
# **Does first exceeding the baseline mean that every later July remained above it? Use the data to explain.**
#
# Your answer: No, July 2023's visitation was below the baseline.

# %% [markdown]
# **Why does this analysis alone not establish that the pandemic caused the 2020 decline?**
#
# Your answer: Any number of factors could have contributed to the 2020 decline. The park may have been going under renovation, or perhaps was closed due to weather.

# %% [markdown]
# # Part 2: Your own investigation

# %% [markdown]
# ## Find a dataset
#
# Find a CSV dataset that interests you. Kaggle is one possible source, but you may use another reputable source. Choose a dataset that:
#
# - has a clearly identified publisher or creator;
# - includes documentation explaining the observations and features;
# - contains at least one categorical and one quantitative feature;
# - is appropriate to share in a class assignment;
# - does not contain private or personally identifying information; and
# - is small enough to run comfortably in this notebook.
#
# Save the CSV in the notebook's `data` folder before continuing.

# %% [markdown]
# **What is the dataset's title, publisher or creator, and direct source URL?**
#
# Your answer:
# Title: Pokemon
# Creator: DivyadeepBhatnagar
# Direct Source: https://www.kaggle.com/datasets/divyadeep/pokemon?resource=download
# (original data likely obtained from Serebii) https://serebii.net/pokedex-sm/

# %% [markdown]
# **What does one row represent?**
#
# Your answer: A species of Pokemon from Generations 1-7 (Sun and Moon)

# %% [markdown]
# ## Step 1: Question
#
# Formulate one research question that can be answered with your dataset. The question must require a calculation or comparison, not merely looking up one value.

# %% [markdown]
# **What is your research question?**
#
# Your answer:
# What (elemental) Type of Pokemon has the highest average Base Stat Total (BST)

# %% [markdown]
# ## Step 2: Data
#
# Read your CSV into a clearly named DataFrame. Display the first and last five rows, information about the DataFrame, and the missing-value count for every feature.

# %%
# Write your code here.
poke_df = pd.read_csv("data/pokemon.csv")

# %%
poke_df.head(5)
# Out:
#    id  Index        Name        Form  ... Defense SpAtk  SpDef  Speed
# 0   1      1   Bulbasaur   Bulbasaur  ...      49    65     65     45
# 1   2      2     Ivysaur     Ivysaur  ...      63    80     80     60
# 2   3      3    Venusaur    Venusaur  ...      83   100    100     80
# 3   4      4  Charmander  Charmander  ...      43    60     50     65
# 4   5      5  Charmeleon  Charmeleon  ...      58    80     65     80
#
# [5 rows x 12 columns]

# %%
poke_df.tail(5)
# Out:
#         id  Index      Name  ... SpAtk SpDef Speed
# 1056  1058    778   Mimikyu  ...   100    60   120
# 1057  1059    778   Mimikyu  ...   100    60   120
# 1058  1060    778   Mimikyu  ...   100    60   120
# 1059  1061    784   Kommo-o  ...   100   105    85
# 1060  1062    801  Magearna  ...   130   115    65
#
# [5 rows x 12 columns]

# %%
poke_df.isnull().sum()
# Not all pokemon have a second elemental type, so that is why there are so many null Type2s
# Out:
# id           0
# Index        0
# Name         0
# Form         0
# Type1        0
# Type2      523
# HP           0
# Attack       0
# Defense      0
# SpAtk        0
# SpDef        0
# Speed        0
# dtype: int64

# %% [markdown]
# **Which observations and features will you use to answer your question?**
#
# Your answer: Type1, Type2, HP, Attack, Defense, SpAtk, SpDef, Speed

# %% [markdown]
# ## Step 3: Operation
#
# Write the code needed to prepare, filter, group, summarize, or sort the data. Store the final evidence in a clearly named object and display it.

# %%
#calculate the bst (Base Stat Total) of each pokemon
poke_df["BST"] = (poke_df["HP"] + poke_df["Attack"] + poke_df["Defense"] + poke_df["SpAtk"] + poke_df["SpDef"] + poke_df["Speed"])
poke_df.head()
# Out:
#    id  Index        Name        Form  Type1  ... Defense  SpAtk  SpDef  Speed  BST
# 0   1      1   Bulbasaur   Bulbasaur  Grass  ...      49     65     65     45  318
# 1   2      2     Ivysaur     Ivysaur  Grass  ...      63     80     80     60  405
# 2   3      3    Venusaur    Venusaur  Grass  ...      83    100    100     80  525
# 3   4      4  Charmander  Charmander   Fire  ...      43     60     50     65  309
# 4   5      5  Charmeleon  Charmeleon   Fire  ...      58     80     65     80  405
#
# [5 rows x 13 columns]

# %%
poke_df.tail()
# Out:
#         id  Index      Name  ... SpDef Speed  BST
# 1056  1058    778   Mimikyu  ...    60   120  500
# 1057  1059    778   Mimikyu  ...    60   120  500
# 1058  1060    778   Mimikyu  ...    60   120  500
# 1059  1061    784   Kommo-o  ...   105    85  600
# 1060  1062    801  Magearna  ...   115    65  600
#
# [5 rows x 13 columns]

# %%
poke_df.head()["HP"].sum()
# Out:
# np.int64(282)

# %%
poke_df.loc[
    (poke_df["Type1"] == "Dragon")
    | (poke_df["Type2"] == "Dragon")
    ]["BST"].mean()
# Out:
# np.float64(538.8387096774194)

# %%
dragons_df = poke_df.loc[
    (poke_df["Type1"] == "Dragon")
    | (poke_df["Type2"] == "Dragon")
    ].copy()
dragons_df
# Out:
#         id  Index       Name  ... SpDef Speed  BST
# 146    147    147    Dratini  ...    50    50  300
# 147    148    148  Dragonair  ...    70    70  420
# 148    149    149  Dragonite  ...   100    80  600
# 229    230    230    Kingdra  ...    95    85  540
# 328    329    329    Vibrava  ...    50    70  340
# ...    ...    ...        ...  ...   ...   ...  ...
# 1012  1014    718    Zygarde  ...    85   115  486
# 1013  1015    718    Zygarde  ...    95    95  600
# 1014  1016    718    Zygarde  ...    95    85  708
# 1040  1042    773   Silvally  ...    95    95  570
# 1059  1061    784    Kommo-o  ...   105    85  600
#
# [62 rows x 13 columns]

# %%
temp = dragons_df.agg(dragon=("id", "count"),
                     mean_bst=("BST", "mean")
    )

temp
# Out:
#             id        BST
# dragon    62.0        NaN
# mean_bst   NaN  538.83871

# %%
tp1_df = poke_df.groupby("Type1").agg(
        count=("Name", "count"),    
        BST_sum=("BST", "sum"),
        BST_mean=("BST", "mean")
    ).sort_values(by="Type1", ascending=True)

tp1_df
# Out:
#           count  BST_sum    BST_mean
# Type1
# Bug         106    42581  401.707547
# Dark         41    18330  447.073171
# Dragon       42    23107  550.166667
# Electric     57    25266  443.263158
# Fairy        34    14934  439.235294
# Fighting     31    13597  438.612903
# Fire         61    28206  462.393443
# Flying        6     3230  538.333333
# Ghost        42    19125  455.357143
# Grass        87    37080  426.206897
# Ground       38    16885  444.342105
# Ice          31    13717  442.483871
# Normal      126    51716  410.444444
# Poison       37    15381  415.702703
# Psychic      93    41137  442.333333
# Rock         67    30884  460.955224
# Steel        32    16228  507.125000
# Water       130    56664  435.876923

# %%
tp2_df = poke_df.groupby("Type2").agg(
        count=("Name", "count"),    
        BST_sum=("BST", "sum"),
        BST_mean=("BST", "mean")
    ).sort_values(by="Type2", ascending=True)
tp2_df
# Out:
#           count  BST_sum    BST_mean
# Type2
# Bug           5     1903  380.600000
# Dark         22    10593  481.500000
# Dragon       20    10301  515.050000
# Electric     12     5317  443.083333
# Fairy        39    17562  450.307692
# Fighting     34    17767  522.558824
# Fire         15     7355  490.333333
# Flying      140    62785  448.464286
# Ghost        18     8265  459.166667
# Grass        32    13170  411.562500
# Ground       42    19107  454.928571
# Ice          15     7838  522.533333
# Normal        7     2725  389.285714
# Poison       35    14071  402.028571
# Psychic      36    17309  480.805556
# Rock         15     6775  451.666667
# Steel        33    16200  490.909091
# Water        18     7415  411.944444

# %%
#combine the counts and sums of both groups, then update the mean values
type_totals = tp1_df.copy()
type_totals["count"] = tp2_df["count"] + tp1_df["count"]
type_totals["BST_sum"] = tp2_df["BST_sum"] + tp1_df["BST_sum"]
type_totals["BST_mean"] = type_totals["BST_sum"] / type_totals["count"]
#sort values by 
type_totals.sort_values("BST_mean", ascending=False, inplace=True)
type_totals
# Out:
#           count  BST_sum    BST_mean
# Type1
# Dragon       62    33408  538.838710
# Steel        65    32428  498.892308
# Fighting     65    31364  482.523077
# Ice          46    21555  468.586957
# Fire         76    35561  467.907895
# Rock         82    37659  459.256098
# Dark         63    28923  459.095238
# Ghost        60    27390  456.500000
# Psychic     129    58446  453.069767
# Flying      146    66015  452.157534
# Ground       80    35992  449.900000
# Fairy        73    32496  445.150685
# Electric     69    30583  443.231884
# Water       148    64079  432.966216
# Grass       119    50250  422.268908
# Normal      133    54441  409.330827
# Poison       72    29452  409.055556
# Bug         111    44484  400.756757

# %% [markdown]
# **Explain how your operations connect the selected data to your research question.**
#
# Your answer:

# %% [markdown]
# ## Step 4: Check
#
# Write at least one check that could reveal an error in your analysis, then display its result.

# %%
# Write your code here.
# Some pokemon have multiple forms, and are thus included multiple times in the data. However, not all forms share stats
forms_df = (poke_df.groupby("Index").agg(
    forms_count=("Index", "count"))
    .sort_values("forms_count", ascending=False))
forms_df.loc[
    forms_df["forms_count"] > 1
    ]
#ex: Pokemon #201 is Unown, it has a form for every letter in the english alphabet plus "!" and "?"
# Out:
#        forms_count
# Index
# 201             28
# 666             20
# 493             18
# 773             18
# 774             14
# ...            ...
# 80               2
# 26               2
# 784              2
# 18               2
# 801              2
#
# [115 rows x 1 columns]

# %%
#check for pokemon that have the same type listed twice (ex: Type1=Normal, type2=Normal)
poke_df.loc[
    poke_df["Type1"] == poke_df["Type2"]
    ]
# Out:
# Empty DataFrame
# Columns: [id, Index, Name, Form, Type1, Type2, HP, Attack, Defense, SpAtk, SpDef, Speed, BST]
# Index: []

# %% [markdown]
# **What did you check, and did the result meet your expectation?**
#
# Your answer: I checked for Pokemon who have multiple forms, and thus appeared multiple times in the data set. The results did meet my expectations.
# Additionally, I also confirmed that no pokemon had the same type listed for Type1 and Type2, thus confirming no one unique pokemon would show up in both groups.

# %% [markdown]
# ## Step 5: Evidence

# %% [markdown]
# **Which specific value or comparison in your output answers the question?**
#
# Your answer: BST_mean

# %% [markdown]
# ## Step 6: Conclusion

# %% [markdown]
# **What conclusion is supported by the evidence?**
#
# Your answer:

# %% [markdown]
# ## Step 7: Limitation

# %% [markdown]
# **What should a reader avoid concluding from your analysis, and why?**
#
# Your answer: The data used only contains pokemon that were released before/during the release of Pokemon Sun and Moon (~November 2016)

# %% [markdown]
# ## AI-use reflection

# %% [markdown]
# **State whether you used an AI tool. If you did, describe one suggestion you checked and what you accepted, changed, or rejected. If you did not, state that you did not use one.**
#
# Your response: I only lightly used Google's AI overview when reasearching how to group the data by the type contained in the Type1 and Type2 column. I wound up using nothing it reccomended, since the results did not fit my needs. I instead opted to separately group the data then add the resulting values together.

# %% [markdown]
# ## Submission checklist
#
# Before submitting, confirm that all cells run in order, the independent dataset and its source are included, every answer is complete, numerical claims match the output, conclusions are appropriately limited, and the AI-use reflection is complete.
